# %%
import pickle
from tqdm import tqdm

# %%
with open("/Users/leon/Documents/GitHub/636-project/data/CSCE-636-Project-1-Train-n_k_m_P", "rb") as f:
    objs = pickle.load(f)

true_max = float("-inf")
true_min = float("inf")

for _, _, _, P in tqdm(objs):
    true_max = max(true_max, P.max())
    true_min = min(true_min, P.min())
# Out:
# 100%|██████████| 96524/96524 [00:00<00:00, 696480.70it/s]

# %%
import numpy as np

a = objs[0][3].astype(np.uint8)

a
# Out:
# dtype('float64')
